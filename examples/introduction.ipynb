# %% [markdown]
# # Introduction

# %%
from bifrost_jupyter_extension.bifrost import plot
import pandas as pd
import numpy as np

# %%
dist = np.random.uniform(0,1, size=(30,2))
data = pd.DataFrame(dist, columns=["x","y"])

# %%
plot(data)
# Out:
# BifrostWidget(graph_spec={'data': {'values': [{'x': 0.9534525587233168, 'y': 0.7493382279257608}, {'x': 0.7244…
#            x         y
# 0   0.953453  0.749338
# 1   0.724459  0.638222
# 2   0.018605  0.702820
# 3   0.825688  0.854146
# 4   0.954855  0.933689
# 5   0.789592  0.562460
# 6   0.944576  0.220121
# 7   0.069007  0.244072
# 8   0.457783  0.187786
# 9   0.461864  0.403343
# 10  0.778345  0.270797
# 11  0.969280  0.958055
# 12  0.605928  0.659336
# 13  0.128287  0.427063
# 14  0.423946  0.467975
# 15  0.109417  0.492654
# 16  0.546230  0.037293
# 17  0.013695  0.711189
# 18  0.154601  0.449373
# 19  0.239497  0.990348
# 20  0.131475  0.063111
# 21  0.101485  0.111072
# 22  0.771542  0.639474
# 23  0.906287  0.283304
# 24  0.068240  0.396870
# 25  0.539591  0.580610
# 26  0.194865  0.861858
# 27  0.207799  0.779841
# 28  0.349012  0.301381
# 29  0.976951  0.728928

# %%
type(list(data.columns)[0])
# Out:
# str
