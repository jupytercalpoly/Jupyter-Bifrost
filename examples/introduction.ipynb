# %% [markdown]
# # Introduction

# %%
from bifrost_jupyter_extension.bifrost import plot
import pandas as pd
import numpy as np

# %%
dist = np.random.uniform(0,1, size=(30,2))
data = pd.DataFrame(dist, columns=["x","y"])

# %%
plot(data)
# Out:
# BifrostWidget(graph_spec={'mark': 'line', 'data': {'values': [{'x': 0.00689062532353768, 'y': 0.00579536705132…
#            x         y
# 0   0.006891  0.005795
# 1   0.961908  0.281317
# 2   0.577674  0.964337
# 3   0.231404  0.121619
# 4   0.321726  0.741356
# 5   0.954977  0.029335
# 6   0.698053  0.157487
# 7   0.414298  0.568264
# 8   0.112450  0.286643
# 9   0.238980  0.827201
# 10  0.302598  0.336599
# 11  0.285824  0.199380
# 12  0.274093  0.223191
# 13  0.568179  0.817592
# 14  0.733695  0.330413
# 15  0.616773  0.335598
# 16  0.899624  0.467814
# 17  0.600531  0.395345
# 18  0.976840  0.196162
# 19  0.981976  0.049989
# 20  0.529324  0.258229
# 21  0.620017  0.708042
# 22  0.343611  0.073276
# 23  0.426703  0.366183
# 24  0.407136  0.360241
# 25  0.875350  0.909791
# 26  0.339184  0.741403
# 27  0.168558  0.152004
# 28  0.022370  0.516423
# 29  0.475929  0.824488
