# %% [markdown]
# # Introduction

# %%
from bifrost_jupyter_extension.bifrost import plot
import pandas as pd
import numpy as np

# %%
dist = np.random.uniform(0,1, size=(30,2))
data = pd.DataFrame(dist, columns=["x","y"])

# %%
plot(data)
# Out:
# BifrostWidget(graph_spec={'mark': 'line', 'data': {'data': [{'x': 0.2267020188002239, 'y': 0.48740809325149803…
#            x         y
# 0   0.226702  0.487408
# 1   0.646926  0.864720
# 2   0.736735  0.050282
# 3   0.383007  0.570932
# 4   0.383742  0.473759
# 5   0.644141  0.567503
# 6   0.299577  0.194893
# 7   0.106014  0.383348
# 8   0.062463  0.161121
# 9   0.223482  0.346191
# 10  0.461772  0.042795
# 11  0.942450  0.314843
# 12  0.133890  0.162717
# 13  0.370613  0.428586
# 14  0.842297  0.310692
# 15  0.507884  0.754299
# 16  0.970001  0.562233
# 17  0.768864  0.959131
# 18  0.538179  0.575967
# 19  0.887078  0.143490
# 20  0.639292  0.416309
# 21  0.707570  0.647025
# 22  0.569151  0.197008
# 23  0.939888  0.971090
# 24  0.083196  0.358592
# 25  0.168326  0.098875
# 26  0.380929  0.257788
# 27  0.222012  0.258744
# 28  0.298316  0.497207
# 29  0.334009  0.457609
