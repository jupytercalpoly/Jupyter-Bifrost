# %% [markdown]
# # Introduction

# %%
from bifrost_jupyter_extension.bifrost import plot
import pandas as pd
import numpy as np

# %%
dist = np.random.uniform(0,1, size=(30,2))
data = pd.DataFrame(dist, columns=["x","y"])

# %%
plot(data)
# Out:
# BifrostWidget(graph_spec={'data': {'data': [{'x': 0.25559732096268617, 'y': 0.3392329938216695}, {'x': 0.36243…
#            x         y
# 0   0.255597  0.339233
# 1   0.362431  0.915534
# 2   0.656285  0.820757
# 3   0.311204  0.905119
# 4   0.253107  0.297951
# 5   0.751098  0.127503
# 6   0.204288  0.140011
# 7   0.623825  0.535142
# 8   0.666225  0.402660
# 9   0.288267  0.865029
# 10  0.152802  0.637153
# 11  0.818151  0.645600
# 12  0.537558  0.457241
# 13  0.706946  0.304120
# 14  0.194427  0.334052
# 15  0.823363  0.127955
# 16  0.609434  0.476600
# 17  0.270505  0.030123
# 18  0.116344  0.801667
# 19  0.892374  0.979731
# 20  0.034598  0.960508
# 21  0.116457  0.266412
# 22  0.576749  0.953837
# 23  0.651737  0.687781
# 24  0.387978  0.638541
# 25  0.910230  0.629621
# 26  0.139175  0.639251
# 27  0.694572  0.228363
# 28  0.003792  0.565043
# 29  0.607553  0.417186
