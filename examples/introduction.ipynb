# %% [markdown]
# # Introduction

# %%
from jupyter_bifrost import Chart
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# %%
cols = ["foo","y", "bar", "baz", "something", "else"]
dist = np.random.uniform(0,1, size=(1000,len(cols)))
scatter_df = pd.DataFrame(dist, columns=cols)

bar_df = pd.DataFrame([
    ["John", "Developer", 1],
    ["Jay", "Developer", 2],
    ["Angela", "Designer", 1],
    ["Brian", "Leader", 20]
], columns=["Name", "Job", "Years Worked For Jupyter"])

iris_ds = load_iris()
iris_df = pd.DataFrame(iris_ds["data"], columns=iris_ds["feature_names"])
titanic_df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv')
iris_df['class'] = ['iris_setosa'] * 50 + ['iris_versicolour'] * 50 + ['iris_virginica'] * 50
# Out:
# Index(['foo', 'y', 'bar', 'baz', 'something', 'else'], dtype='object')
# Index(['Name', 'Job', 'Years Worked For Jupyter'], dtype='object')
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'class'],
#       dtype='object')

# %%
chart = Chart('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv')

# %%
chart.plot()
# Out:
# {'name': 'graph_data_config', 'old': {'sampleSize': 100, 'datasetLength': 0}, 'new': {'sampleSize': 100, 'datasetLength': 891}, 'owner': BifrostWidget(column_name_map={'survived': 'survived', 'pclass': 'pclass', 'sex': 'sex', 'age': 'age', 'sibsp': 'sibsp', 'parch': 'parch', 'fare': 'fare', 'embarked': 'embarked', 'class': 'class', 'who': 'who', 'adult_male': 'adult_male', 'deck': 'deck', 'embark_town': 'embark_town', 'alive': 'alive', 'alone': 'alone'}, column_types={'survived': 'quantitative', 'pclass': 'quantitative', 'sex': 'nominal', 'age': 'quantitative', 'sibsp': 'quantitative', 'parch': 'quantitative', 'fare': 'quantitative', 'embarked': 'nominal', 'class': 'nominal', 'who': 'nominal', 'adult_male': 'nominal', 'deck': 'nominal', 'embark_town': 'nominal', 'alive': 'nominal', 'alone': 'nominal'}, df_columns=['adult_male', 'age', 'alive', 'alone', 'class', 'deck', 'embark_town', 'embarked', 'fare', 'parch', 'pclass', 'sex', 'sibsp', 'survived', 'who'], graph_data=[{'survived': 0, 'pclass': 2, 'sex': 'male', 'age': 36.0, 'sibsp': 1, 'parch': 2, 'fare': 27.75, 'embarked': 'S', 'class': 'Second', 'who': 'man', 'adult_male': True, 'deck': None, 'embark_town': 'Southampton', 'alive': 'no', 'alone': False}, {'survived': 1, 'pclass': 1, 'sex': 'female', 'age': None, 'sibsp': 1, 'parch': 0, 'fare': 89.1042, 'embarked': 'C', 'class': 'First', 'who': 'woman', 'adult_male': False, 'deck': 'C', 'embark_town': 'Cherbourg', 'alive': 'yes', 'alone': False}, {'survived': 0, 'pclass': 3, 'sex': 'male', 'age': None, 'sibsp': 0, 'parch': 0, 'fare': 7.725, 'embarked': 'Q', 'class': 'Third', 'who': 'man', 'adult_male': True, 'deck': None, 'embark_town': 'Queenstown', 'alive': 'no', 'alone': True}, {'survived': 0, 'pclass': 3, 'sex': 'male', 'age': None, 'sibsp': 0, 'parch': 0, 'fare': 7.75, 'embarked': 'Q', 'class': 'Third', 'who': 'man', 'adult_male': True, 'deck': None, 'embark_town': 'Queenstown', 'alive': 'no', 'alone': True}, {'survived': 0, 'pclass': 3, 'sex': 'male', 'age': 30.0, 'sibsp': 0, 'parch': 0, 'fare': 7.2292, 'embarked': 'C', 'class': 'Third', 'who': 'man', 'adult_male': True, 'deck': None, 'embark_town': 'Cherbourg', 'alive': 'no', 'alone': True}, {'survived': 0, 'pclass': 3, 'sex': 'male', 'age': 17.0, 'sibsp': 1, 'parch': 0, 'fare': 7.0542, 'embarked': 'S', 'class': 'Third', 'who': 'man', 'adult_male': True, 'deck': None, 'embark_town': 'Southampton', 'alive': 'no', 'alone': False}, {'survived': 0, 'pclass': 3, 'sex': 'male', 'age': 42.0, 'sibsp': 0, 'parch': 0, 'fare': 7.65, 'embarked': 'S', 'class': 'Third', 'who': 'man', 'adult_male': True, 'deck': 'F', 'embark_town': 'Southampton', 'alive': 'no', 'alone': True}, {'survived': 1, 'pclass': 3, 'sex': 'female', 'age': 4.0, 'sibsp': 0, 'parch': 1, 'fare': 13.4167, 'embarked': 'C', 'class': 'Third', 'who': 'child', 'adult_male': False, 'deck': None, 'embark_town': 'Cherbourg', 'alive': 'yes', 'alone': False}, {'survived': 1, 'pclass': 1, 'sex': 'female', 'age': 19.0, 'sibsp': 0, 'parch': 2, 'fare': 26.2833, 'embarked': 'S', 'class': 'First', 'who': 'woman', 'adult_male': False, 'deck': 'D', 'embark_town': 'Southampton', 'alive': 'yes', 'alone': False}, {'survived': 0, 'pclass': 1, 'sex': 'male', 'age': 50.0, 'sibsp': 1, 'parch': 0, 'fare': 106.425, 'embarked': 'C', 'class': 'First', 'who': 'man', 'adult_male': True, 'deck': 'C', 'embark_town': 'Cherbourg', 'alive': 'no', 'alone': False}, {'survived': 0, 'pclass': 2, 'sex': 'male', 'age': 30.0, 'sibsp': 0, 'parch': 0, 'fare': 10.5, 'embarked': 'S', 'class': 'Second', 'who': 'man', 'adult_male': True, 'deck': None, 'embark_town': 'Southampton', 'alive': 'no', 'alone': True}, {'survived': 0, 'pclass': 3, 'sex': 'male', 'age': 17.0, 'sibsp': 1, 'parch': 1, 'fare': 7.2292, 'embarked': 'C', 'class': 'Third', 'who': 'man', 'adult_male': True, 'deck': None, 'embark_town': 'Cherbourg', 'alive': 'no', 'alone': False}, {'survived': 0, 'pclass': 3, 'sex': 'female', 'age': None, 'sibsp': 3, 'parch': 1, 'fare': 25.4667, 'embarked': 'S', ' ...
# BifrostWidget(column_name_map={'survived': 'survived', 'pclass': 'pclass', 'sex': 'sex', 'age': 'age', 'sibsp'…
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]
