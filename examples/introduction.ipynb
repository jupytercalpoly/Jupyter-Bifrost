# %% [markdown]
# # Introduction

# %%
from bifrost_jupyter_extension.bifrost import plot
import pandas as pd
import numpy as np

# %%
dist = np.random.uniform(0,1, size=(30,2))
data = pd.DataFrame(dist, columns=["x","y"])

# %%
plot(data)
# Out:
# BifrostWidget(graph_spec={'mark': 'line', 'data': {'values': [{'x': 0.7150536644686396, 'y': 0.019761952564081…
#            x         y
# 0   0.715054  0.019762
# 1   0.925345  0.481265
# 2   0.156158  0.927003
# 3   0.889820  0.614968
# 4   0.077491  0.953485
# 5   0.320299  0.754507
# 6   0.719286  0.399822
# 7   0.342477  0.720044
# 8   0.294543  0.566026
# 9   0.817163  0.748940
# 10  0.129708  0.815401
# 11  0.640201  0.543340
# 12  0.830538  0.260682
# 13  0.047278  0.494736
# 14  0.414213  0.147873
# 15  0.303128  0.737994
# 16  0.032853  0.913314
# 17  0.664163  0.028150
# 18  0.302811  0.603431
# 19  0.316945  0.685997
# 20  0.403144  0.446850
# 21  0.339706  0.892161
# 22  0.587221  0.782650
# 23  0.803448  0.939043
# 24  0.714661  0.968885
# 25  0.223908  0.678212
# 26  0.330931  0.795659
# 27  0.742709  0.123047
# 28  0.458913  0.971651
# 29  0.950970  0.493088
